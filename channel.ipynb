# %% [markdown]
# Notebook for collecting audience usernames for a channel

# %%
# Limit calls to stay under API quota
COMMENT_CAP = 50 # This gets multiplied by 100
VIDEO_CAP = 1 # This gets multiplied by 25

# %%
import os
import csv
from googleapiclient.discovery import build
from dotenv import load_dotenv

# %%
# Load YOUTUBE_API_KEY from .env file
load_dotenv()  
API_KEY = os.getenv('YOUTUBE_API_KEY')
youtube = build("youtube", "v3", developerKey=API_KEY)

# %%
# Get all usernames from a video's comments, including replies
def get_video_usernames(video_id, cap):
    usernames = []
    next_page_token = None
    count = 0
    
    while count < cap:
        count = count + 1

        try:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token
            )
            response = request.execute()
        except Exception as e:
            # HttpError when comments are disabled.
            print(e)
            return usernames
        
        for item in response.get("items", []):
            usernames.append(item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"])
            
            if 'replies' in item:
                for reply in item['replies']['comments']:
                    usernames.append(reply["snippet"]["authorDisplayName"])
        
        next_page_token = response.get("nextPageToken")
        
        if not next_page_token:
            break
    
    return usernames

# %%
# Append usernames from video to channel audience csv
def append_usernames_to_csv(file_path, usernames):
    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        for username in usernames:
            try:
                writer.writerow([username])
            except UnicodeEncodeError:
                print(f"Occurence of non UTF-8 character.")

# %%
def get_channel_id_by_custom_url(url):
    request = youtube.search().list(
        part='snippet',
        q=url,
        type='channel'
    )
    response = request.execute()
    
    if 'items' in response and response['items']:
        channel_id = response['items'][0]['id']['channelId']
        return channel_id
    else:
        return None

# %%
def get_video_ids(channel_id, cap):
    video_ids = []
    next_page_token = None
    count = 0
    
    while count < cap:
        count = count + 1
        
        playlists_response = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()
        
        playlist_id = playlists_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        
        playlist_items_response = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=25,
            pageToken=next_page_token
        ).execute()
        
        video_ids.extend(item['contentDetails']['videoId'] for item in playlist_items_response['items'])
        
        next_page_token = playlist_items_response.get('nextPageToken')
        if not next_page_token:
            break
    
    return video_ids

# %%
# Get audience for CHANNEL (a youtube channel's custom URL)
def get_audience(channel):
        # create empty csv for channel
        file_path = f"Channels/{channel}.csv"
        with open(file_path, mode='w', encoding='utf-8') as file:
                pass

        channel_id = get_channel_id_by_custom_url(channel)

        video_ids = get_video_ids(channel_id, VIDEO_CAP)
        num_videos = len(video_ids)
        print(f"{num_videos} videos found.")

        count = 1
        for video_id in video_ids:
                usernames  = get_video_usernames(video_id, COMMENT_CAP)
                print(f"{count}/{num_videos}, {video_id}: {len(usernames)}")
                count = count + 1
                append_usernames_to_csv(file_path, usernames)

# %%
with open('channels_to_run.txt', 'r') as file:
    channels = file.readlines()

for channel in channels:
    channel = channel.strip()
    if channel:
        print(f"---- {channel} ----")
        get_audience(channel)
# Out:
# ---- ZullietheWitch ----
# 25 videos found.
# 1/25, 15oxX3C-PYM: 799
# 2/25, 0T--MrFL97c: 922
# 3/25, 0Aijnyn1NEA: 731
# 4/25, nHjsz9oXh94: 739
# 5/25, 0KoGwQjKlEA: 782
# 6/25, TW61dH1m57Y: 547
# 7/25, P7t-gXCD98o: 1716
# Occurence of non UTF-8 character.
# 8/25, G3CtGilQkpY: 650
# 9/25, 9oGgq3E4Tbg: 1113
# 10/25, itipQQjJHnI: 1006
# 11/25, X4xE5amx3aI: 1421
# Occurence of non UTF-8 character.
# 12/25, JbL2aQubNlw: 684
# Occurence of non UTF-8 character.
# 13/25, yxy20EpQGB4: 961
# 14/25, m3YAIq-gNYo: 1137
# 15/25, SQDBseP14lE: 948
# 16/25, AC6ja5B--30: 603
# 17/25, cxQD_tGucv0: 1141
# 18/25, 1m3Cf0Qf39I: 929
# Occurence of non UTF-8 character.
# 19/25, 4dUrFFGrHYE: 519
# Occurence of non UTF-8 character.
# 20/25, nRUX5MhccVE: 930
# Occurence of non UTF-8 character.
# 21/25, ScJcgXtKls8: 858
# 22/25, glzoAUIiA4c: 1028
# 23/25, ILJBtBOQ2P8: 1290
# 24/25, FECFxyNpLbs: 505
# 25/25, mJ-AAPVvALY: 495
# ---- kiwami-japan ----
# 25 videos found.
# 1/25, Q1VWUL0G0uU: 5685
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 2/25, eh0IaUn4z9k: 5326
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 3/25, yBIeavntc5U: 5433
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 4/25, WIkDjTwyc00: 5628
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 5/25, 01WzbuO7_ms: 5662
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 6/25, MFCNUvFEVFY: 5661
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 7/25, qm9N_SPhwR8: 5378
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 8/25, BNP15d-cgu8: 5661
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 9/25, D2XNVFlh-DU: 5617
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 10/25, pFG-nXUw6Ts: 5783
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=t_j6rlMSQ_g&maxResults=100&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpZElCZ0JFZ1VJaUNBWUFCSUZDS2dnR0FBU0JRaUhJQmdBR0FBaURRb0xDT1RubU84RkVMajk3azA%3D&key=AIzaSyD1V09USoaBvY9-DAarMDF4eT_lmsnLbFY&alt=json returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.". Details: "[{'message': "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.", 'domain': 'youtube.commentThread', 'reason': 'processingFailure', 'location': 'body', 'locationType': 'other'}]">
# 11/25, t_j6rlMSQ_g: 3756
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 12/25, WZJ7nSdIbwk: 5786
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 13/25, 24LC_2r3dwU: 5706
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 14/25, d7_WDPGNOZ4: 5820
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 15/25, JKi85QNr7zo: 5623
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 16/25, Rax37KtyWOk: 5687
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 17/25, NkWhNVWx0VU: 5607
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 18/25, RUlHhrL_Zj8: 5761
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 19/25, uA57xOX3AvA: 5642
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 20/25, vZLlUsqXzE8: 5579
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 21/25, AMYKQc-MVIM: 5776
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 22/25, 9M79vDyKaG0: 5776
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 23/25, FgdHZqSIO1M: 5657
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 24/25, 92Cr__DPOME: 5690
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 25/25, t557dPspLxo: 5882
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# ---- sanago ----
# 25 videos found.
# 1/25, 0bfXpUvF6wY: 90
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 2/25, xo_6_aZMwuE: 1051
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 3/25, JT2HsF6lC6A: 84
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 4/25, VSG-JeTs92s: 1964
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 5/25, LkJNiL-KBuY: 5117
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 6/25, nijCVqJH5YM: 2122
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 7/25, 5yUGn4n6IXI: 462
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 8/25, iQHk78K7hN4: 272
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 9/25, _B-MVBhBtD4: 993
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 10/25, gcFyPUalTfA: 866
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 11/25, o-mDyjjLG5c: 1587
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 12/25, rin2MeMdO7M: 981
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 13/25, vJJi8MofVXA: 464
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 14/25, p8tpqM80a1A: 798
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 15/25, ba1LSdrYU2A: 1028
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 16/25, xctdH0aDaMk: 4010
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 17/25, QnPDnrzGc34: 1236
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 18/25, fdAEsnuE4RU: 919
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 19/25, hsuCzSu5uS4: 785
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 20/25, Si-BjD287yI: 801
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 21/25, S9mCaXKp39M: 161
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 22/25, 7jitvQXaU1I: 868
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 23/25, wPLI0VOV-JM: 163
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 24/25, AqhM-qRH4m8: 463
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# 25/25, lWgMQ-vnOUA: 5195
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
