# %% [markdown]
# Notebook for collecting audience usernames for a channel

# %%
# EDIT THIS:
CHANNEL = "TYLER1LOL"

# Limit calls to stay under API quota
COMMENT_CAP = 50 # This gets multiplied by 100
VIDEO_CAP = 1 # This gets multiplied by 25

# %%
import os
import csv
from googleapiclient.discovery import build
from dotenv import load_dotenv

# %%
# Load YOUTUBE_API_KEY from .env file
load_dotenv()  
API_KEY = os.getenv('YOUTUBE_API_KEY')
youtube = build("youtube", "v3", developerKey=API_KEY)

# %%
# Get all usernames from a video's comments, including replies
def get_video_usernames(video_id, cap):
    usernames = []
    next_page_token = None
    count = 0
    
    while count < cap:
        count = count + 1

        request = youtube.commentThreads().list(
            part="snippet,replies",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token
        )
        response = request.execute()
        
        for item in response.get("items", []):
            usernames.append(item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"])
            
            if 'replies' in item:
                for reply in item['replies']['comments']:
                    usernames.append(reply["snippet"]["authorDisplayName"])
        
        next_page_token = response.get("nextPageToken")
        
        if not next_page_token:
            break
    
    return usernames

# %%
# Append usernames from video to channel audience csv
def append_usernames_to_csv(file_path, usernames):
    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        for username in usernames:
            try:
                writer.writerow([username])
            except UnicodeEncodeError:
                print(f"Occurence of non UTF-8 character.")

# %%
def get_channel_id_by_custom_url(url):
    request = youtube.search().list(
        part='snippet',
        q=url,
        type='channel'
    )
    response = request.execute()
    
    if 'items' in response and response['items']:
        channel_id = response['items'][0]['id']['channelId']
        return channel_id
    else:
        return None

#custom_url = 'RedLetterMedia'
#channel_id = get_channel_id_by_custom_url(custom_url)
#print(f'Channel ID: {channel_id}')

# %%
def get_video_ids(channel_id, cap):
    video_ids = []
    next_page_token = None
    count = 0
    
    while count < cap:
        count = count + 1
        
        playlists_response = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()
        
        playlist_id = playlists_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        
        playlist_items_response = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=25,
            pageToken=next_page_token
        ).execute()
        
        video_ids.extend(item['contentDetails']['videoId'] for item in playlist_items_response['items'])
        
        next_page_token = playlist_items_response.get('nextPageToken')
        if not next_page_token:
            break
    
    return video_ids

#video_ids = get_video_ids(channel_id)
#print(len(video_ids))

# %%
# Get audience for CHANNEL (a youtube channel's custom URL)

# create empty csv for channel
file_path = f"Channels/{CHANNEL}.csv"
with open(file_path, mode='w', encoding='utf-8') as file:
        pass

channel_id = get_channel_id_by_custom_url(CHANNEL)

video_ids = get_video_ids(channel_id, VIDEO_CAP)
num_videos = len(video_ids)
print(f"{num_videos} videos found.")

count = 1
for video_id in video_ids:
    usernames  = get_video_usernames(video_id, COMMENT_CAP)
    print(f"{count}/{num_videos}, {video_id}: {len(usernames)}")
    count = count + 1
    append_usernames_to_csv(file_path, usernames)
# Out:
# 826 videos found.
# 21gl2hgjo7A: 3288
# YieefGRusWQ: 5078
# BOZ99Zw8dmw: 3089
# 5Ub2uT2z14w: 989
# Pu0sIzDAH_Y: 1683
# vkqXLLg0VZw: 1815
# X-6WBWmoVEY: 12505
# pygCruE-EJs: 3212
# Occurence of non UTF-8 character.
# 1g9_uw5XjyM: 1148
# MwO5fGL2MeY: 8730
# TD1qwkCOqRo: 2633
# dcqYEq5ANFA: 1841
# Qzt5zmqu-ac: 1985
# k2x1yP2cpE8: 2569
# wuLbH_ljnHs: 2287
# COgA_kSfgLE: 1961
# ELcY7nWaZVE: 1497
# iTc2uuWE_ZE: 2949
# Occurence of non UTF-8 character.
# _h2pU6lLW4g: 6993
# RgnN62S02xg: 4357
# OFIpmRoRAGU: 7300
# BwJYg2vk4fA: 2932
# Occurence of non UTF-8 character.
# X1nspyaDEEU: 2688
# EFLTbPQUNVo: 4374
# UsaTdqhd6eg: 5719
# KSvsGbarbfs: 3754
# Occurence of non UTF-8 character.
# U3RBuVpwsFQ: 8048
# At1EOyY5Hpo: 5362
# yaILVoXZTqU: 4517
# SyJBP1X1mLE: 5349
# U8Wqvq3BrYg: 2285
# aQ2TQ_GRO4g: 4569
# FbLk4ktAE5U: 3279
# Khcf1hWX1B4: 3494
# SP2HJ_XppbU: 4952
# HgNKJhT74jU: 2871
# k6n-vo8rgF0: 1509
# JCU21cRMGgk: 2069
# cd1eNS9HtXo: 6150
# jHxpFHY1z-A: 4326
# a7ueE94SGnA: 2885
# Occurence of non UTF-8 character.
# qOzsy6IHNUM: 2408
# rpSo4fu1rgM: 8208
# Occurence of non UTF-8 character.
# FBEYOlXNAC8: 4640
# Occurence of non UTF-8 character.
# bN-vjBGpqeA: 1195
# 5jPtkjxU5jg: 1754
# 4ClY9yo7-9o: 4998
# nMtrjNPcjR0: 8712
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Uhi-YAkz2vk: 4400
# Occurence of non UTF-8 character.
# BuIemfjmIak: 3501
# R5xa7r6oIBQ: 3930
# K71JAJMWeco: 5296
# dSuKs44w_vI: 2843
# EEpRbgXT0z4: 1768
# Occurence of non UTF-8 character.
# zyBjbqKPIj0: 3848
# Occurence of non UTF-8 character.
# H_Nt1_TWdv0: 3893
# Occurence of non UTF-8 character.
# x-JPhAM5ugE: 4244
# Occurence of non UTF-8 character.
# DZZf3VHwrMQ: 2591
# ZOAZlCvNC_0: 2568
# Occurence of non UTF-8 character.
# -40wXsVTcjc: 2804
# iPwNociLraM: 2797
# -XspNUpGZ9c: 1867
# Occurence of non UTF-8 character.
# bV67EpIAkAg: 8891
# Occurence of non UTF-8 character.
# zQwR1CSqMe0: 3991
# x7QNqz2pSak: 2013
# Occurence of non UTF-8 character.
# 1fXACfkyvLc: 2138
# RTosyCJQrmA: 4514
# mESbAwiCaTw: 4153
# Occurence of non UTF-8 character.
# wqf4lOZEank: 3462
# KKQiJuXN07E: 6022
# Occurence of non UTF-8 character.
# Ko0fKuy8z2U: 5881
# Occurence of non UTF-8 character.
# folpZj0ORf0: 2855
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# eTeLD5KVtHE: 2427
# M2MgjPrSVX0: 5255
# jm0aYVYJrfQ: 6956
# RXrzuqElB2U: 2077
# Occurence of non UTF-8 character.
# 8Y4BFKZLRUU: 4082
# NgBgpkip58k: 3587
# vNp3Q0AfXRg: 7903
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# fyBv_h2nyXk: 6247
# eFCp5XG9rX4: 3783
# livSYU_jwCw: 3222
# _8qGSkcX6R0: 2483
# I_MFjQ9L-Po: 1266
# Occurence of non UTF-8 character.
# OXyZeqb1aj8: 2113
# xPLvqG2adTw: 4215
# hBOrprigQu8: 3216
# H1xzKd5of2I: 2448
# 19xIhMVZ5g4: 1551
# HhkBleDMvB0: 7559
# rrstrOrJxOc: 2194
# nQxOLpkRWzw: 4998
# Occurence of non UTF-8 character.
# 5yQ-4EPXVrM: 1468
# Occurence of non UTF-8 character.
# Pe03wFRySok: 2002
# Xto-7_xWb9g: 3316
# RUacNo-MM-E: 1675
# BathEBfiG1s: 3019
# Occurence of non UTF-8 character.
# yAlnLnxeIOI: 4592
# DXWTfamqgMg: 3914
# N-px3CZv0zI: 913
# Zs13fJuP0F4: 4497
# mSFGoon-5Wc: 2099
# -F0jtrV3RxI: 4077
# Occurence of non UTF-8 character.
# 1sJM0_xyO1c: 1753
# IuhKIW2FLaA: 2388
# 3tx33tgXT3M: 3185
# Occurence of non UTF-8 character.
# Occurence of non UTF-8 character.
# Gwrl6P5c1R0: 3328
# FaSNvI7oShk: 4086
# jlUyVq5RmaI: 4790
# m-hGLHOzvgs: 4395
# lwM4TIFRpMc: 1963
# pF28Zednl10: 5989
# o4eSVXCzRyI: 5560
# uNz4H4V-SBI: 1748
# WcFlmIR02Uw: 2236
# kuS8ek6OM44: 3345
# pQS_bX3sX8s: 1959
# h5htSJ1C7ts: 5756
# Occurence of non UTF-8 character.
# 0DNDkx9pQxk: 2838
# TwF1iri1GjQ: 11393
# Occurence of non UTF-8 character.
# KnM2Purvp10: 2248
# 9Jy2APnVIbk: 1837
# T6mtQeJaTUI: 2906
# Ao99bNrJ_1Q: 2130
# Q-gk8cHCo4Y: 2140
# tKmMRSTUeAs: 3543
# 7uSkQq3NbO8: 2029
# GyGGW3tqNPY: 5155
# YAa_m9H-PGs: 2041
# eHhLZi4sj0k: 3209
# MiqElS_RfPw: 2874
# Uv-wmixiiMA: 5964
# GkDmRy6SP28: 3817
# 6c-hAbInjt4: 3703
# 9M39zY9OXFA: 4295
# hfQdf93e63I: 8107
# UMkMSoBdFAc: 4198
# hoel2EiTjLU: 1791
# Efskcq_mqv4: 6348
# z0eSyLb6FE0: 3896
# 5pAsss_nTlk: 17430
# Occurence of non UTF-8 character.
# ScgaYFvuBFM: 2578
# UCIYCaXNe88: 4914
# Occurence of non UTF-8 character.
# 5vzSPROcX1U: 3108
# wEW_qMxLBLc: 1861
# Occurence of non UTF-8 character.
# f07ZuJmRRQw: 1697
# ZaLlMQHTISI: 3086
# Hugsy-pQ61U: 4992
# Occurence of non UTF-8 character.
# X7_ZU4dlqXk: 3734
# 26si7WjhV-g: 3196
# NIC6D77YYgY: 2286
# nAGA82ajAdo: 6655
# lb3hIEcRu34: 2028
# feH2sxYGE-w: 3221
# A-RoBdHHkcQ: 2375
# xIxCrkR5FPQ: 2624
# m2IV0BajqAk: 3004
# qejGHLAbo_c: 5032
# Occurence of non UTF-8 character.
# ngrVbx5xoh0: 1553
# WNYF6XmsRJM: 1519
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25324/1439143030.py in <module>
#      12
#      13 for video_id in video_ids:
# ---> 14     usernames  = get_video_usernames(video_id)
#      15     print(f"{video_id}: {len(usernames)}")
#      16     append_usernames_to_csv(file_path, usernames)
#
# ~\AppData\Local\Temp/ipykernel_25324/1975367655.py in get_video_usernames(video_id)
#      11             pageToken=next_page_token
#      12         )
# ---> 13         response = request.execute()
#      14
#      15         for item in response.get("items", []):
#
# c:\Users\Evan\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# c:\Users\Evan\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=7PeEAqARU0E&maxResults=100&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpZElCZ0JFZ1VJcUNBWUFCSUZDSWtnR0FBU0JRaUhJQmdBR0FBaURRb0xDSm0td3VvRkVOQ1cybm8%3D&key=AIzaSyD1V09USoaBvY9-DAarMDF4eT_lmsnLbFY&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
